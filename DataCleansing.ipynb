# %%
# %matplotlib inline
import sys
print(sys.version)
import numpy as np
print(np.__version__)
import pandas as pd
print(pd.__version__)
import matplotlib.pyplot as plt
# Out:
# 3.5.1 (v3.5.1:37a07cee5969, Dec  6 2015, 01:54:25) [MSC v.1900 64 bit (AMD64)]
# 1.11.0rc1
# 0.18.0rc1

# %%
# Convert all columns to string
df = pd.read_csv(r'.\FInalDataset.csv',dtype='str')
print(type(df))
df.head(10)
print(df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (1048575, 19)

# %%
# ?pd.read_csv()

# %%
df.dtypes
# Out:
# EnterpriseID           object
# LAST                   object
# FIRST                  object
# MIDDLE                 object
# SUFFIX                 object
# DOB                    object
# GENDER                 object
# SSN                    object
# ADDRESS1               object
# ADDRESS2               object
# ZIP                    object
# MOTHERS_MAIDEN_NAME    object
# MRN                    object
# CITY                   object
# STATE                  object
# PHONE                  object
# PHONE2                 object
# EMAIL                  object
# ALIAS                  object
# dtype: object

# %%
df.columns
# Out:
# Index(['EnterpriseID', 'LAST', 'FIRST', 'MIDDLE', 'SUFFIX', 'DOB', 'GENDER',
#        'SSN', 'ADDRESS1', 'ADDRESS2', 'ZIP', 'MOTHERS_MAIDEN_NAME', 'MRN',
#        'CITY', 'STATE', 'PHONE', 'PHONE2', 'EMAIL', 'ALIAS'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1048575, step=1)

# %%
df.count()
# Out:
# EnterpriseID           1000000
# LAST                    966743
# FIRST                   966116
# MIDDLE                  382290
# SUFFIX                    9047
# DOB                     983537
# GENDER                  989941
# SSN                     755394
# ADDRESS1                931347
# ADDRESS2                690361
# ZIP                     928393
# MOTHERS_MAIDEN_NAME      49172
# MRN                     463042
# CITY                    927284
# STATE                   926313
# PHONE                   978124
# PHONE2                  146330
# EMAIL                   235851
# ALIAS                    54133
# dtype: int64

# %%
# Combine First and Last Name
df['NAME'] = df[['FIRST','LAST']].apply(lambda x : '{} {}'.format(x[0],x[1]), axis=1)
df.head(5)
# Out:
#   EnterpriseID       LAST   FIRST    MIDDLE SUFFIX        DOB  GENDER  \
# 0     13125316   BERRYMAN  MARTHA       NaN    NaN   8/6/1993  FEMALE
# 1     14423865   DESCHOMP  HAROLD       NaN    NaN  6/13/1973    MALE
# 2     15058700     THOMAS      JO  JOSEFINA    NaN  5/26/1990  FEMALE
# 3     14377701  CHEVALIER   AULIO       NaN    NaN  5/14/2014    MALE
# 4     14946687  CERVANTES    LEAH       NaN    NaN  1/26/1990  FEMALE
#
#            SSN            ADDRESS1 ADDRESS2    ZIP MOTHERS_MAIDEN_NAME  MRN  \
# 0  857-46-5079       1120 CLAY AVE       4G  10456                 NaN  NaN
# 1  822-36-9891      1172 E 73RD ST      PVT  11224                 NaN  NaN
# 2  882-90-8105  1780 LAFAYETTE AVE       1B  10473                 NaN  NaN
# 3  877-20-3599       330 FIRST AVE      NaN  10029                 NaN  NaN
# 4          NaN    755 WHITE PLS RD      24K  10473                 NaN  NaN
#
#        CITY STATE         PHONE        PHONE2 EMAIL ALIAS             NAME
# ...

# %%
df.DOB.value_counts()
# Out:
# 2/24/2003     63
# 6/14/2002     62
# 9/10/2005     60
# 9/16/1991     60
# 7/27/2007     60
# 2/3/2002      60
# 8/3/2008      59
# 5/25/2002     58
# 2/6/1992      58
# 6/23/2007     58
# 5/17/2005     58
# 6/6/2007      58
# 6/2/1998      57
# 4/26/2004     57
# 2/5/2005      57
# 7/20/2007     57
# 3/28/2003     57
# 4/24/2007     56
# 11/1/1990     56
# 3/29/2001     56
# 2/21/2008     56
# 2/11/1998     56
# 5/10/2004     56
# 3/27/1997     56
# 6/20/2003     56
# 10/4/2007     56
# 9/6/2004      56
# 4/24/2006     56
# 11/12/1994    56
# 6/26/2006     56
#               ..
# 12/13/1969     1
# 10/10/1902     1
# 12/25/1916     1
# 11/28/1900     1
# 12/20/1926     1
# 12/21/1968     1
# 11/5/1907      1
# 7/31/1984      1
# 7/31/1954      1
# 12/3/1905      1
# 6/30/1990      1
# 8/30/1906      1
# 12/10/1906     1
# 12/18/1958     1
# 12/19/2015     1
# 12/30/1957     1
# 12/21/1945     1
# 12/23/1930     1
# 12/10/2016     1
# 12/4/1941      1
# 2/28/1973      1
# ...

# %%
# Convert DOB field to MMDDYYYY
df['DOB'] = pd.to_datetime(df['DOB']).dt.strftime('%m%d%Y')
df.head(5)
# Out:
#   EnterpriseID       LAST   FIRST    MIDDLE SUFFIX       DOB  GENDER  \
# 0     13125316   BERRYMAN  MARTHA       NaN    NaN  08061993  FEMALE
# 1     14423865   DESCHOMP  HAROLD       NaN    NaN  06131973    MALE
# 2     15058700     THOMAS      JO  JOSEFINA    NaN  05261990  FEMALE
# 3     14377701  CHEVALIER   AULIO       NaN    NaN  05142014    MALE
# 4     14946687  CERVANTES    LEAH       NaN    NaN  01261990  FEMALE
#
#            SSN            ADDRESS1 ADDRESS2    ZIP MOTHERS_MAIDEN_NAME  MRN  \
# 0  857-46-5079       1120 CLAY AVE       4G  10456                 NaN  NaN
# 1  822-36-9891      1172 E 73RD ST      PVT  11224                 NaN  NaN
# 2  882-90-8105  1780 LAFAYETTE AVE       1B  10473                 NaN  NaN
# 3  877-20-3599       330 FIRST AVE      NaN  10029                 NaN  NaN
# 4          NaN    755 WHITE PLS RD      24K  10473                 NaN  NaN
#
#        CITY STATE         PHONE        PHONE2 EMAIL ALIAS             NAME
# ...

# %%
df.GENDER.value_counts()
# Out:
# MALE      440393
# FEMALE    431921
# F          59053
# M          48541
# U          10033
# Name: GENDER, dtype: int64

# %%
# Coverting M as MALE; F as FEMALE; U as missing
df['GENDER'] = df['GENDER'].apply(lambda x : 'M' if x == 'MALE' else 'F' if x == 'FEMALE' else x)
df.head(5)
# Out:
#   EnterpriseID       LAST   FIRST    MIDDLE SUFFIX       DOB GENDER  \
# 0     13125316   BERRYMAN  MARTHA       NaN    NaN  08061993      F
# 1     14423865   DESCHOMP  HAROLD       NaN    NaN  06131973      M
# 2     15058700     THOMAS      JO  JOSEFINA    NaN  05261990      F
# 3     14377701  CHEVALIER   AULIO       NaN    NaN  05142014      M
# 4     14946687  CERVANTES    LEAH       NaN    NaN  01261990      F
#
#            SSN            ADDRESS1 ADDRESS2    ZIP MOTHERS_MAIDEN_NAME  MRN  \
# 0  857-46-5079       1120 CLAY AVE       4G  10456                 NaN  NaN
# 1  822-36-9891      1172 E 73RD ST      PVT  11224                 NaN  NaN
# 2  882-90-8105  1780 LAFAYETTE AVE       1B  10473                 NaN  NaN
# 3  877-20-3599       330 FIRST AVE      NaN  10029                 NaN  NaN
# 4          NaN    755 WHITE PLS RD      24K  10473                 NaN  NaN
#
#        CITY STATE         PHONE        PHONE2 EMAIL ALIAS             NAME
# ...

# %%
df.GENDER.value_counts()
# Out:
# F    490974
# M    488934
# U     10033
# Name: GENDER, dtype: int64

# %%
df.SSN.value_counts()
# Out:
# 000-00-0000    64
# 999-99-9999    53
# 123-45-6789    52
# 666-66-6666    48
# 111-11-1111    48
# 888-88-8888    45
# 555-55-5555    43
# 777-77-7777    42
# 333-33-3333    42
# 444-44-4444    41
# 222-22-2222    38
# 432-10-9876    29
# 654-32-1098    27
# 109-87-6543    27
# 000-00-0001    23
# 098-76-5432    23
# 765-43-2109    23
# 901-23-4567    22
# 678-90-1234    22
# 876-54-3210    22
# 789-01-2345    22
# 210-98-7654    22
# 456-78-9012    20
# 234-56-7890    19
# 890-12-3456    19
# 321-09-8765    18
# 543-21-0987    17
# 567-89-0123    15
# 345-67-8901    13
# 861-79-1258     3
#                ..
# 826-32-5859     1
# 880-62-9560     1
# 865-34-2706     1
# 830-97-3404     1
# 862-07-7875     1
# 800-42-4325     1
# 825-29-5612     1
# 845-06-9688     1
# 823-19-0755     1
# 862-36-7823     1
# 802-67-3839     1
# 850-10-6189     1
# 821-39-7261     1
# 865-09-3760     1
# 882-96-1212     1
# 848-26-0317     1
# 805-61-9429     1
# 883-03-0943     1
# 848-18-1553     1
# ...

# %%
import re
# Convert SSN to a string without hyphens and ensure correct length
# Some of the SSN's are assigned to multiple people, they should all be considered missing
df['SSN'] = df['SSN'].apply(lambda x : re.split("-",str(x),3))
df['SSN'] = df['SSN'].apply(lambda x : "".join(x))
df['SSN'] = df['SSN'].apply(lambda x : x if len(x) == 9 else 'NaN')
df.head(5)
# Out:
#   EnterpriseID       LAST   FIRST    MIDDLE SUFFIX       DOB GENDER  \
# 0     13125316   BERRYMAN  MARTHA       NaN    NaN  08061993      F
# 1     14423865   DESCHOMP  HAROLD       NaN    NaN  06131973      M
# 2     15058700     THOMAS      JO  JOSEFINA    NaN  05261990      F
# 3     14377701  CHEVALIER   AULIO       NaN    NaN  05142014      M
# 4     14946687  CERVANTES    LEAH       NaN    NaN  01261990      F
#
#          SSN            ADDRESS1 ADDRESS2    ZIP MOTHERS_MAIDEN_NAME  MRN  \
# 0  857465079       1120 CLAY AVE       4G  10456                 NaN  NaN
# 1  822369891      1172 E 73RD ST      PVT  11224                 NaN  NaN
# 2  882908105  1780 LAFAYETTE AVE       1B  10473                 NaN  NaN
# 3  877203599       330 FIRST AVE      NaN  10029                 NaN  NaN
# 4        NaN    755 WHITE PLS RD      24K  10473                 NaN  NaN
#
#        CITY STATE         PHONE        PHONE2 EMAIL ALIAS             NAME
# ...

# %%
df.STATE.value_counts()
# Out:
# NY          920392
# NJ            2528
# PA             557
# FL             545
# CT             493
# NC             187
# MA             185
# VA             184
# CA             149
# MD             134
# GA             115
# SC              83
# TX              79
# UN              62
# OH              42
# MI              37
# IL              36
# PR              34
# RI              33
# NH              31
# OS              30
# DC              28
# WA              27
# DE              25
# AZ              23
# IN              22
# ZZ              20
# MN              19
# CO              19
# ME              17
#              ...
# HI              10
# AL              10
# VT               9
# KY               7
# WV               7
# OK               7
# NM               6
# OR               6
# UT               5
# AR               5
# NV               4
# MS               3
# Y                2
# WY               2
# VI               2
# SD               2
# ...

# %%
# Trim the State field and force any value that is not in the following list to missing
states=['AL','AK','AZ','AR','CA','CO','CT','DE','DC','FL','GA','HI','ID','IL','IN','IA','KS',
        'KY','LA','ME','MT','NE','NV','NH','NJ','NM','NY','NC','ND','OH','OK','OR','MD','MA',
        'MI','MN','MS','MO','PA','RI','SC','SD','TN','TX','UT','VT','VA','WA','WV','WI','WY']
df['STATE'] = df['STATE'].apply(lambda x : x if x in states else 'NaN')
df.head(5)
# Out:
#   EnterpriseID       LAST   FIRST    MIDDLE SUFFIX       DOB GENDER  \
# 0     13125316   BERRYMAN  MARTHA       NaN    NaN  08061993      F
# 1     14423865   DESCHOMP  HAROLD       NaN    NaN  06131973      M
# 2     15058700     THOMAS      JO  JOSEFINA    NaN  05261990      F
# 3     14377701  CHEVALIER   AULIO       NaN    NaN  05142014      M
# 4     14946687  CERVANTES    LEAH       NaN    NaN  01261990      F
#
#          SSN            ADDRESS1 ADDRESS2    ZIP MOTHERS_MAIDEN_NAME  MRN  \
# 0  857465079       1120 CLAY AVE       4G  10456                 NaN  NaN
# 1  822369891      1172 E 73RD ST      PVT  11224                 NaN  NaN
# 2  882908105  1780 LAFAYETTE AVE       1B  10473                 NaN  NaN
# 3  877203599       330 FIRST AVE      NaN  10029                 NaN  NaN
# 4        NaN    755 WHITE PLS RD      24K  10473                 NaN  NaN
#
#        CITY STATE         PHONE        PHONE2 EMAIL ALIAS             NAME
# ...

# %%
df.STATE.value_counts()
# Out:
# NY     920392
# NaN    122433
# NJ       2528
# PA        557
# FL        545
# CT        493
# NC        187
# MA        185
# VA        184
# CA        149
# MD        134
# GA        115
# SC         83
# TX         79
# OH         42
# MI         37
# IL         36
# RI         33
# NH         31
# DC         28
# WA         27
# DE         25
# AZ         23
# IN         22
# MN         19
# CO         19
# ME         17
# KS         14
# LA         13
# WI         13
# TN         12
# MO         12
# HI         10
# AL         10
# VT          9
# OK          7
# KY          7
# WV          7
# NM          6
# OR          6
# UT          5
# AR          5
# NV          4
# MS          3
# WY          2
# SD          2
# IA          1
# NE          1
# AK          1
# MT          1
# ND          1
# Name: STATE, dtype: int64

# %%
df.PHONE.value_counts()
# Out:
# 5555555555      62
# 9999999999      60
# 777-777-7777    57
# 666-666-6666    57
# 222-222-2222    57
# 555-555-5555    55
# 333-333-3333    53
# 1111111111      53
# 111-111-1111    53
# 8888888888      52
# 4444444444      51
# 444-444-4444    49
# 2222222222      49
# 999-999-9999    49
# 6666666666      48
# 123-456-7890    44
# 888-888-8888    44
# 7777777777      43
# 3333333333      43
# 000-000-0000    38
# 0               33
# 1234567890      18
# 973-779-2175     4
# 848-792-3592     4
# 934-497-5518     4
# 518-910-9327     4
# 609-764-3506     4
# 908-690-8520     4
# 609-261-1019     3
# 934-789-8080     3
#                 ..
# 610-874-6882     1
# 848-671-9951     1
# 267-244-8160     1
# 212-759-9973     1
# 212-576-8469     1
# 203-174-6319     1
# 908-926-7621     1
# 201-811-2725     1
# 267-783-2988     1
# 518-665-2209     1
# 201-136-4236     1
# 845-333-2216     1
# 203-607-6108     1
# 518-436-5633     1
# 718-300-2234     1
# 347-915-7581     1
# ...

# %%
#Trim Phone, dropping all hyphens and slashes, and forcing any record that is not of length 10 to missing
df['PHONE'] = df['PHONE'].apply(lambda x : re.split("-",str(x),3))
df['PHONE'] = df['PHONE'].apply(lambda x : "".join(x))
df['PHONE'] = df['PHONE'].apply(lambda x : x if len(x) == 10 else 'NaN')
df.head(5)
# Out:
#   EnterpriseID       LAST   FIRST    MIDDLE SUFFIX       DOB GENDER  \
# 0     13125316   BERRYMAN  MARTHA       NaN    NaN  08061993      F
# 1     14423865   DESCHOMP  HAROLD       NaN    NaN  06131973      M
# 2     15058700     THOMAS      JO  JOSEFINA    NaN  05261990      F
# 3     14377701  CHEVALIER   AULIO       NaN    NaN  05142014      M
# 4     14946687  CERVANTES    LEAH       NaN    NaN  01261990      F
#
#          SSN            ADDRESS1 ADDRESS2    ZIP MOTHERS_MAIDEN_NAME  MRN  \
# 0  857465079       1120 CLAY AVE       4G  10456                 NaN  NaN
# 1  822369891      1172 E 73RD ST      PVT  11224                 NaN  NaN
# 2  882908105  1780 LAFAYETTE AVE       1B  10473                 NaN  NaN
# 3  877203599       330 FIRST AVE      NaN  10029                 NaN  NaN
# 4        NaN    755 WHITE PLS RD      24K  10473                 NaN  NaN
#
#        CITY STATE       PHONE        PHONE2 EMAIL ALIAS             NAME
# ...

# %%
df.PHONE.value_counts()
# Out:
# NaN           70496
# 5555555555      117
# 9999999999      109
# 2222222222      106
# 1111111111      106
# 6666666666      105
# 7777777777      100
# 4444444444      100
# 8888888888       96
# 3333333333       96
# 1234567890       62
# 0000000000       38
# 9344975518        4
# 8487923592        4
# 9086908520        4
# 9737792175        4
# 5189109327        4
# 6097643506        4
# 3477062566        3
# 8627364912        3
# 6099961961        3
# 5169908224        3
# 5515004063        3
# 9177638130        3
# 5185995547        3
# 5513801930        3
# 5186381225        3
# 6104374825        3
# 5518867028        3
# 9736726960        3
#               ...
# 8603141573        1
# 6318069948        1
# 8455824657        1
# 3478512613        1
# 5705936476        1
# 2033415390        1
# 5182019398        1
# 7181841988        1
# 9732432981        1
# 8627569064        1
# 9737008858        1
# 5513597448        1
# 6091961956        1
# 6091813462        1
# ...

# %%
df.head(50)
# Out:
#    EnterpriseID        LAST      FIRST    MIDDLE SUFFIX       DOB GENDER  \
# 0      13125316    BERRYMAN     MARTHA       NaN    NaN  08061993      F
# 1      14423865    DESCHOMP     HAROLD       NaN    NaN  06131973      M
# 2      15058700      THOMAS         JO  JOSEFINA    NaN  05261990      F
# 3      14377701   CHEVALIER      AULIO       NaN    NaN  05142014      M
# 4      14946687   CERVANTES       LEAH       NaN    NaN  01261990      F
# 5      14593403    PETERSEN      LINDA       NaN    NaN  09232011      F
# 6      12726346        FORD    CRYSTAL   LYNETTE    NaN  09131924      F
# 7      12950013       HAGIN       PAUL   TIMOTHY    NaN  01092007      M
# 8      14600091   KOROTCHEN     AURORA       NaN    NaN  07021939      F
# 9      14156155       MILES      NORMA     TAMMY    NaN  09161964      F
# 10     12224307      POTTER       LISA       NaN    NaN  05161951      F
# 11     12821612        MIAO    LEE YEN       NaN    NaN  05041988      F
# ...
